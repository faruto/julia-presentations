# %% [markdown]
# # Explore NYC Housing data

# %%
using DataFrames

# %%
housing = readtable("housing.csv")
# Out:
# DataFrame with 2626 rows, 13 columns
# Columns:
#
# Neighborhood                 2626 non-null values
# Building.Classification      2626 non-null values
# Total.Units                  2626 non-null values
# Year.Built                   2530 non-null values
# Gross.SqFt                   2626 non-null values
# Estimated.Gross.Income       2626 non-null values
# Gross.Income.per.SqFt        2626 non-null values
# Estimated.Expense            2626 non-null values
# Expense.per.SqFt             2626 non-null values
# Net.Operating.Income         2626 non-null values
# Full.Market.Value            2626 non-null values
# Market.Value.per.SqFt        2626 non-null values
# Boro                         2626 non-null values

# %%
typeof(ans)
# Out:
# DataFrame (constructor with 22 methods)

# %%
colnames(housing)
# Out:
# 13-element Array{Union(ASCIIString,UTF8String),1}:
#  "Neighborhood"
#  "Building.Classification"
#  "Total.Units"
#  "Year.Built"
#  "Gross.SqFt"
#  "Estimated.Gross.Income"
#  "Gross.Income.per.SqFt"
#  "Estimated.Expense"
#  "Expense.per.SqFt"
#  "Net.Operating.Income"
#  "Full.Market.Value"
#  "Market.Value.per.SqFt"
#  "Boro"

# %%
;head housing.csv
# Out:
# stty: stdin isn't a terminal
# Neighborhood,Building.Classification,Total.Units,Year.Built,Gross.SqFt,Estimated.Gross.Income,Gross.Income.per.SqFt,Estimated.Expense,Expense.per.SqFt,Net.Operating.Income,Full.Market.Value,Market.Value.per.SqFt,Boro
# FINANCIAL,R9-CONDOMINIUM,42,1920,36500,1332615,36.51,342005,9.37,990610,7300000,200,Manhattan
# FINANCIAL,R4-CONDOMINIUM,78,1985,126420,6633257,52.47,1762295,13.94,4870962,30690000,242.76,Manhattan
# FINANCIAL,RR-CONDOMINIUM,500,NA,554174,17310000,31.24,3543000,6.39,13767000,90970000,164.15,Manhattan
# FINANCIAL,R4-CONDOMINIUM,282,1930,249076,11776313,47.28,2784670,11.18,8991643,67556006,271.23,Manhattan
# TRIBECA,R4-CONDOMINIUM,239,1985,219495,10004582,45.58,2783197,12.68,7221385,54320996,247.48,Manhattan
# TRIBECA,R4-CONDOMINIUM,133,1986,139719,5127687,36.7,1497788,10.72,3629899,26737996,191.37,Manhattan
# TRIBECA,R4-CONDOMINIUM,109,1985,105000,4365900,41.58,1273650,12.13,3092250,22210281,211.53,Manhattan
# TRIBECA,R4-CONDOMINIUM,107,1986,87479,3637377,41.58,1061120,12.13,2576257,19449002,222.33,Manhattan
# TRIBECA,R4-CONDOMINIUM,247,1987,255845,11246946,43.96,2440761,9.54,8806185,66316999,259.21,Manhattan

# %%
describe(housing)
# Out:
# Neighborhood
# Length  2626
# Type    UTF8String
# NAs     0
# NA%     0.0%
# Unique  151
#
# Building.Classification
# Length  2626
# Type    UTF8String
# NAs     0
# NA%     0.0%
# Unique  4
#
# Total.Units
# Min      1.0
# 1st Qu.  15.0
# Median   30.0
# Mean     70.18392993145468
# 3rd Qu.  75.0
# Max      3378.0
# NAs      0
# NA%      0.0%
#
# Year.Built
# Min      1825.0
# 1st Qu.  1926.0
# Median   1986.0
# Mean     1967.4604743083005
# 3rd Qu.  2005.0
# Max      2010.0
# NAs      96
# NA%      3.66%
#
# Gross.SqFt
# Min      478.0
# 1st Qu.  18704.5
# Median   38455.5
# Mean     82762.86557501904
# 3rd Qu.  90626.25
# Max      3.364977e6
# NAs      0
# NA%      0.0%
#
# Estimated.Gross.Income
# Min      6424.0
# 1st Qu.  405180.0
# Median   943901.0
# Mean     2.640881935262757e6
# 3rd Qu.  2.7255505e6
# Max      5.6010967e7
# NAs      0
# NA%      0.0%
#
# Gross.Income.per.SqFt
# Min      3.57
# 1st Qu.  18.79
# Median   25.0
# Mean     27.57213632901752
# 3rd Qu.  36.82
# Max      62.8
# NAs      0
# NA%      0.0%
#
# Estimated.Expense
# Min      1740.0
# 1st Qu.  155514.75
# Median   350263.5
# Mean     840916.0811119573
# 3rd Qu.  899084.5
# Max      2.1771401e7
# NAs      0
# NA%      0.0%
#
# Expense.per.SqFt
# Min      0.97
# 1st Qu.  7.64
# Median   9.18
# Mean     9.400316070068543
# 3rd Qu.  11.05
# Max      18.21
# NAs      0
# NA%      0.0%
#
# Net.Operating.Income
# Min      4684.0
# 1st Qu.  239699.75
# Median   581522.5
# Mean     1.7999658541507998e6
# 3rd Qu.  1.80514925e6
# Max      4.0144686e7
# NAs      0
# NA%      0.0%
#
# Full.Market.Value
# Min      30000.0
# 1st Qu.  1.67775025e6
# Median   4.0264995e6
# Mean     1.2977807587966489e7
# 3rd Qu.  1.31367525e7
# Max      2.95182007e8
# NAs      0
# NA%      0.0%
#
# Market.Value.per.SqFt
# Min      10.66
# 1st Qu.  74.6325
# Median   112.22
# Mean     131.1872048743336
# 3rd Qu.  187.49
# Max      399.38
# NAs      0
# NA%      0.0%
#
# Boro
# Length  2626
# Type    UTF8String
# NAs     0
# NA%     0.0%
# Unique  5

# %%
using Gadfly
set_default_plot_size(9inch,9inch/golden);

# %%
plot(housing, x="Gross.SqFt", y="Estimated.Expense")
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,116602,9223372036854775807,116603),false,0,[],[],1,5,[0xb543bae82e60b36c=>([115.80912710708361,109.61497069533526,101.84897551605334,105.15619772540575,105.16262176021168,110.7685363262996,111.74604502509804,112.67292901512042,106.65605066910594,111.93163116028559  …  116.3301368274432,115.83271679090251,115.52254886463145,115.83271679090251,115.83271679090251,115.87759781071769,114.5224012217206,114.36196607684245,112.18942554006358,114.14815867266023],1),0x4c18125752760b74=>([42.094203537735844,46.091020292452825,65.10408028018867,51.54290592264151,50.22807233254717,46.68214202311321,45.138931603773585,44.36014794764151,51.84377839386792,45.18911405613207  …  42.03695376037736,42.600028433962265,43.33929729811321,42.600028433962265,42.600028433962265,43.2450218495283,44.499672055660376,43.97895688349057,47.88194267547169,45.31068093584905],0)],true,true)
# Plot(...)

# %%
plot(housing, x="Gross.SqFt", y="Estimated.Expense", Scale.x_log, Scale.y_log10, color="Boro")
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,241844,9223372036854775807,241845),false,0,[],[],1,5,[0x3d38bd608f3d3f5b=>(["geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan","geometry color_Manhattan"  …  "geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island","geometry color_Staten_Island"],2),0xcff7a9e547bb00e2=>([96.17111310982017,114.64970148774202,136.6323060494306,124.73683866572199,122.85627261557815,116.1375048465633,111.88825502325005,109.17273755142688,125.13568012626513,112.04733788278006  …  95.63674081675609,100.20784619674245,104.64273697160556,100.20784619674245,100.20784619674245,104.14547823585298,109.69712572290027,107.63799094109189,118.76485986505364,112.42580629494105],0),0xd83724306d5e4068=>([LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0),LCHab(65.0,70.0,0.0)  …  LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435),LCHab(80.0,70.0,315.6521739130435)],4),0x22a1a8a76b502b35=>([62.04367467085934,46.516827166539265,39.90324313909417,42.1840898555351,42.189100612675766,48.05694398617086,49.59208871139835,51.32098705602772,43.43244774188232,49.913904937151365  …  66.1131976138247,62.194648313484336,60.379328505500034,62.194648313484336,62.194648313484336,62.488706480551116,56.15306467471254,55.62140230403119,50.379895328015884,54.95630406919727],1),0x8160b566978d1d8e=>({LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0),LCHab(50.0,70.0,0.0)  …  LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435),LCHab(65.0,70.0,315.6521739130435)},3)],true,true)
# Plot(...)

# %%
plot(housing, x="Gross.Income.per.SqFt", Geom.histogram, color="Boro")
# Out:
# D3(228.6,141.28256982822595,IOBuffer([0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x74,0x5f,0x69,0x64,0x29,0x3b,0x0a,0x7d,0x3b,0x0a],true,true,true,false,201561,9223372036854775807,201562),false,0,[],[],0,5,Dict{Uint64,(Any,Int64)}(),true,true)
# Plot(...)
